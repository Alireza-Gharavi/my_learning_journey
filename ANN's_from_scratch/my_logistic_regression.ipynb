# %% [markdown]
# ### implementing logitic regression on

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data = pd.read_csv('../datasets/Fish.csv')
data.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
Xs , Ys = data[['Height']] , data[['Roach']]
plt.scatter(data.Height, data.Species)
plt.show()

# %%
data = data.loc[data['Species'].isin(['Bream', 'Roach'])]
Xs , Ys = data.Height, data.Species
plt.scatter(Xs, Ys)
